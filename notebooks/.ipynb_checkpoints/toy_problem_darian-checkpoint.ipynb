# %% [markdown]
# # Multi-Fidelity Bayesian Optimization: Investigating a Minimal Toy Problem

# %% [markdown]
# ## Notes
# We'll need to maintain a multioutput Gaussian Process surrogate for multifidelity Bayesian optimization. When using Gaussian Processes in the multifidelity scenario, one option is to extend the surrogate model through an autoregressive scheme:
# $$
# f^{(l)} = \rho f^{(l-1)}(\textbf{x}) + \delta^{l}(\textbf{x}), \;\; l = 2, \dots, L
# $$
# where $\delta^{l}(\textbf{x}) \sim \mathcal{GP}(0, \kappa^{(l)}(\textbf{x}, \textbf{x}'))$ models the discrepancy between two adjoining levels of fidelity, and $\rho$ is a constant scaling factor.
#
# ## Desideratum
# - [ ] We'll need a mechanism for computing covariances between input-fidelity pairs.
#     - This poses a natural question: How do we choose our kernel function for evaluating the covariance between different fidelity levels?
# - [x] Figure out if the white noise kernel is for ensuring the invertability of our linear system.
# - [ ] Add support for optimize surrogates with arbitrary sum and product kernels.
#     - The issue right now is that the constructor for each kernel needs to be provided to Optim and a manner that allows us to reconstruct the kernel iteratively for optimization

# %% [markdown]
# ## Minimal Problem Exploration
# To make sense of the methodology presented in `Non-Myopic Multifidelity Bayesian Optimization`, we'll reduce our problem to the simplest instance of the generalized problem. That is, we only consider two fidelity measures via the autoregressive scheme:
# $$
#     f^{(2)} = \rho f^{(1)}(\textbf{x}) + \delta^{2}(\textbf{x})
# $$

# %% [markdown]
# Given some arbitrary $\textbf{x}$, we know our

# %% [markdown]
# ## Surrogate and Kernel Setup

# %%
using Plots; plot() # warm start plotting engine
using LinearAlgebra
using Distributions
using Optim
using DelimitedFiles

# %%
include("../src/utils.jl")
include("../src/testfns.jl")
include("../src/kernels.jl")
include("../src/surrogates.jl")
include("../src/acquisitions.jl")
include("../src/optimizers.jl")
# Out:
# optimize_surrogate (generic function with 1 method)

# %% [markdown]
# ## 1. Gather Initial Samples
# Our first step is to run some initial experiments and collect our data locations into some matrix $X$ and observations into some vector $y$. Our "experiments" will be random evaluations of some test function; in practice, our function is black-boxed.

# %%
N, ϵ = 21, 1e-2
# testfn, testfn_name, X, y = get_toy_problem(N=N, fn_name="Rastrigin")
testfn = TestLinearPlusCosine1D(1., 5., lb=0., ub=10.)
X = randsample(N, testfn.dim, testfn.bounds[:, 1], testfn.bounds[:, 2])
y = testfn(X) .+ ϵ * randn(N)
tplot(testfn)

# %%
GP(first(kernel.ψconstructor()), X, y, noise=ϵ)
# Out:
# MethodError: no method matching GP(::var"#squared_exponential#2222"{Float64}, ::Matrix{Float64}, ::Vector{Float64}; noise::Float64)
#
# Closest candidates are:
#   GP(::Kernel, ::AbstractMatrix, ::AbstractVector; noise)
#    @ Main ~/Documents/academia/cornell-university/research/projects/multi-fidelity-bayesian-optimization/src/surrogates.jl:58
#
#
# Stacktrace:
#  [1] top-level scope
#    @ In[50]:1

# %%
kernel.ψconstructor()[1]
kernel
# Out:
# Kernel([1.0], var"#squared_exponential#2222"{Float64}(1.0), var"#squared_exponential_hypers#2223"(), var"#2160#2166"{var"#squared_exponential#2222"{Float64}}(var"#squared_exponential#2222"{Float64}(1.0)), var"#2162#2168"{var"#squared_exponential#2222"{Float64}}(var"#squared_exponential#2222"{Float64}(1.0)), var"#2164#2170"{Vector{Float64}, var"#squared_exponential_hypers#2223"}([1.0], var"#squared_exponential_hypers#2223"()), SquaredExponentialConstructor)

# %% [markdown]
# ## 2. Initialize the surrogate model

# %%
# kernel = Periodic(1., 1.)# + SquaredExponential()
kernel = SquaredExponential()
sur = optimize_surrogate(
    gp=GP(kernel, X, y, noise=ϵ),
    kernel_constructor=kernel.ψconstructor,
    lbs=0.1 * ones(length(kernel)),
    ubs=5. * ones(length(kernel)),
    noise=ϵ
)

domain = get_dense_grid(testfn)
plot1d(sur, interval=domain)
plot!(domain, [testfn([x]) for x in domain], label="Objective")
scatter!(sur.X', get_observations(sur), label=nothing)
# Out:
# [0.3659459668672659]
# MethodError: no method matching GP(::Tuple{var"#squared_exponential#2220"{Vector{Vector{Float64}}}, var"#squared_exponential_hypers#2221"}, ::Matrix{Float64}, ::Vector{Float64}; noise::Float64)
#
# Closest candidates are:
#   GP(::Kernel, ::AbstractMatrix, ::AbstractVector; noise)
#    @ Main ~/Documents/academia/cornell-university/research/projects/multi-fidelity-bayesian-optimization/src/surrogates.jl:58
#
#
# Stacktrace:
#   [1] (::var"#_∇log_likelihood!#2246"{Float64, typeof(SquaredExponentialConstructor), Matrix{Float64}, Vector{Float64}})(g::Vector{Float64}, θ::Vector{Float64})
#     @ Main ~/Documents/academia/cornell-university/research/projects/multi-fidelity-bayesian-optimization/src/optimizers.jl:13
#   [2] (::NLSolversBase.var"#fg!#8"{var"#_log_likelihood#2245"{Float64, typeof(SquaredExponentialConstructor), Matrix{Float64}, Vector{Float64}}, var"#_∇log_likelihood!#2246"{Float64, typeof(SquaredExponentialConstructor), Matrix{Float64}, Vector{Float64}}})(gx::Vector{Float64}, x::Vector{Float64})
#     @ NLSolversBase ~/.julia/packages/NLSolversBase/kavn7/src/objective_types/abstract.jl:13
#   [3] value_gradient!!(obj::OnceDifferentiable{Float64, Vector{Float64}, Vector{Float64}}, x::Vector{Float64})
#     @ NLSolversBase ~/.julia/packages/NLSolversBase/kavn7/src/interface.jl:82
#   [4] value_gradient!!(bw::Optim.BarrierWrapper{OnceDifferentiable{Float64, Vector{Float64}, Vector{Float64}}, Optim.BoxBarrier{Vector{Float64}, Vector{Float64}}, Float64, Float64, Vector{Float64}}, x::Vector{Float64})
#     @ Optim ~/.julia/packages/Optim/DV9Sq/src/multivariate/solvers/constrained/fminbox.jl:81
#   [5] initial_state(method::LBFGS{Optim.InverseDiagonal, LineSearches.InitialStatic{Float64}, LineSearches.HagerZhang{Float64, Base.RefValue{Bool}}, Optim.var"#68#69"{Vector{Float64}, Vector{Float64}, Fminbox{LBFGS{Nothing, LineSearches.InitialStatic{Float64}, LineSearches.HagerZhang{Float64, Base.RefValue{Bool}}, Optim.var"#19#21"}, Float64, Optim.var"#51#53"}, Optim.BarrierWrapper{OnceDifferentiable{Float64, Vector{Float64}, Vector{Float64}}, Optim.BoxBarrier{Vector{Float64}, Vector{Float64}}, Float64, Float64, Vector{Float64}}}}, options::Optim.Options{Float64, Nothing}, d::Optim.BarrierWrapper{OnceDifferentiable{Float64, Vector{Float64}, Vector{Float64}}, Optim.BoxBarrier{Vector{Float64}, Vector{Float64}}, Float64, Float64, Vector{Float64}}, initial_x::Vector{Float64})
#     @ Optim ~/.julia/packages/Optim/DV9Sq/src/multivariate/solvers/first_order/l_bfgs.jl:164
#   [6] optimize(df::OnceDifferentiable{Float64, Vector{Float64}, Vector{Float64}}, l::Vector{Float64}, u::Vector{Float64}, initial_x::Vector{Float64}, F::Fminbox{LBFGS{Nothing, LineSearches.InitialStatic{Float64}, LineSearches.HagerZhang{Float64, Base.RefValue{Bool}}, Optim.var"#19#21"}, Float64, Optim.var"#51#53"}, options::Optim.Options{Float64, Nothing})
#     @ Optim ~/.julia/packages/Optim/DV9Sq/src/multivariate/solvers/constrained/fminbox.jl:322
#   [7] #optimize#55
#     @ ~/.julia/packages/Optim/DV9Sq/src/multivariate/solvers/constrained/fminbox.jl:244 [inlined]
#   [8] optimize(f::Function, g::Function, l::Vector{Float64}, u::Vector{Float64}, initial_x::Vector{Float64}, F::Fminbox{LBFGS{Nothing, LineSearches.InitialStatic{Float64}, LineSearches.HagerZhang{Float64, Base.RefValue{Bool}}, Optim.var"#19#21"}, Float64, Optim.var"#51#53"}, options::Optim.Options{Float64, Nothing})
#     @ Optim ~/.julia/packages/Optim/DV9Sq/src/multivariate/solvers/constrained/fminbox.jl:233
#   [9] optimize_surrogate(; gp::GaussianProcess, kernel_constructor::typeof(SquaredExponentialConstructor), lbs::Vector{Float64}, ubs::Vector{Float64}, noise::Float64, random_restarts::Int64, max_iterations::Int64)
#     @ Main ~/Documents/academia/cornell-university/research/projects/multi-fidelity-bayesian-optimization/src/optimizers.jl:35
#  [10] top-level scope
#     @ In[46]:3

# %%
(SquaredExponential() + Periodic(1., 1.)).ψconstructor
# Out:
# SquaredExponentialConstructor (generic function with 3 methods)

# %%
SquaredExponential()([1.], [1.])
# Out:
# 1.0

# %%
SquaredExponential().ψconstructor()[1]([1.], [1.])
# Out:
# 1.0

# %%
sur.k.θ
# Out:
# 3-element Vector{Float64}:
#  1.0
#  1.0
#  1.0

# %% [markdown]
# ## On Computing and Optimizing Acquisition Functions

# %%
X = rand(2,2)
# Out:
# 2×2 Matrix{Float64}:
#  0.847335   0.261391
#  0.0690158  0.30879

# %%
hcat(X, rand(2))
# Out:
# 2×3 Matrix{Float64}:
#  0.847335   0.261391  0.578482
#  0.0690158  0.30879   0.813792

# %%
X
# Out:
# 2×2 Matrix{Float64}:
#  0.847335   0.261391
#  0.0690158  0.30879

# %%
β = 2.
UCB = UCB_constructor(sur)(β)
LCB = LCB_constructor(sur)(β)
gp_mean = UCB_constructor(sur)(0.)
domain = get_dense_grid(testfn)

plot(domain, [UCB([x]) for x in domain], label="UCB(x; β=$β)")
# plot!(domain, [LCB([x]) for x in domain], label="LCB(x; β=$β)")
# plot!(domain, [gp_mean([x]) for x in domain], label="μ")

# %%
lbs, ubs = testfn.bounds[:, 1], testfn.bounds[:, 2]
results = []

for x0 in range(first(lbs) + .01, first(ubs) - .01, length=16)
    print("|")
    push!(results, optimize(
            x -> -UCB(x), lbs, ubs, [x0], Fminbox(LBFGS()), Optim.Options(x_tol=1e-3, f_tol=1e-3)
        )
    )
end
# Out:
# ||||||||||||||||

# %%
xx, yy = first.(Optim.minimizer.(results)), Optim.minimum.(results)
scatter!(xx, -yy, label=nothing)

# %% [markdown]
# ## Gaussian Process Regression for Nonlinear Time Series

# %%
data = readdlm("../data/co2_mm_mlo.csv", ',');

year, month, co2 = data[2:end, 1], data[2:end, 2], data[2:end, 4];
year_month = similar(year)

# Combine year and month into a single variable where the fractional part of
# the variable represents the month
for (i, payload) in enumerate(zip(year, month))
    cur_year, cur_month = payload
    year_month[i] = cur_year + cur_month / 12.
end

xtrain = year_month[year_month.<2018]; ytrain = co2[year_month.<2018];
xtest = year_month[year_month.>=2018]; ytest = co2[year_month.>=2018];

# %%
kernel = sum([
    4SquaredExponential(4.0),
    Periodic(1., 12.)*SquaredExponential(4.0,),
    RationalQuadratic(1., 1.0) + SquaredExponential(2.)
])
GP = ZeroMeanGP(kernel, xtrain', ytrain, noise=1e-3);

# %%
plot1d(GP, interval=minimum(xtest):.01:maximum(xtest))

# %% [markdown]
# ## On Modeling Separable Gaussian Processes via Additive Kernels
# Given a random process $f(x) = f_1(x) + f_2(x)$, where $f_1, f_2$ are independent, then $k(x, y) = k_1(x, y) + k_2(x, y)$. Given a kernel $k: \chi^2 \to \mathbb{R}$ where $\chi \subset \mathbb{R}^d$ we know that adding a kernel or multiplying by a kernel results in another kernel.

# %%
kernels = [
    SquaredExponential(.5),
    Periodic(1., 1.1),
    Periodic(.5, .5),
]
kernel = sum(kernels)
surs = []
noise = 0.

for (i, k) in enumerate(kernels)
    noise_i = Int(i - 1 <= 0) * noise
    push!(surs, ZeroMeanGP(k, X, y; noise=noise_i))
end

sur = ZeroMeanGP(kernel, X, y; noise=noise);
